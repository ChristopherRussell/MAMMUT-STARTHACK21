# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as ani
import math
import pandas as pd

# %%
h5_file_name = 'raw_overhang.h5'
f = h5py.File(h5_file_name, 'r')

# %%
l = f['acc_LH']
l = np.asarray(l)
l['timestamp'] -= l['timestamp'][0]

# %%
l
# Out:
# array([(1.61426058e+09,  0.84572893, 0.20459609, -0.46534623),
#        (1.61426058e+09,  0.93300729, 0.05722444, -0.4586692 ),
#        (1.61426058e+09,  0.85128629, 0.04905697, -0.48271922), ...,
#        (1.61426107e+09, -0.65794191, 0.48750122, -0.60324462),
#        (1.61426107e+09, -0.66191545, 0.4914989 , -0.59885817),
#        (1.61426107e+09, -0.68482122, 0.52350162, -0.59367264)],
#       dtype=[('timestamp', '<f8'), ('AP', '<f8'), ('UR', '<f8'), ('DP', '<f8')])

# %%
plt.plot(l['timestamp'], l['AP'])
plt.plot(l['timestamp'], l['UR'])
plt.plot(l['timestamp'], l['DP'])

# %%
norm = (l['AP'] ** 2 + l['UR'] ** 2 + l['DP'] ** 2) ** 0.5

# %%
plt.plot(l['timestamp'], norm)

# %%
norm.min()
# Out:
# 0.1039057240711483
